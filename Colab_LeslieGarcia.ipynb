# %% [markdown]
# <a href="https://colab.research.google.com/github/leslierogarcia/Modulo_1/blob/main/Colab_LeslieGarcia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es mi primer cuarderno
# Aquí voy a mezclar código Markdown con operaciones matemáticas:
# - Suma
# - Resta
# - División
# - Multiplicación

# %%
a=30
b=15
a+b
# Out:
# 45

# %%
a=67
b=11
a-b
# Out:
# 56

# %%
a=1200
b=60
a/b
# Out:
# 20.0

# %%
import matplotlib.pyplot as plt
a = 81
b = 12
resultado = a * b
eje_x = [0, b]
eje_y = [0, resultado]
plt.step(eje_x, eje_y, color='blue', where='post', linewidth=2)
plt.title('perdida de liquido')
plt.xlabel('segundos')
plt.ylabel('resultado de la multiplicación')
print(f"Resultado de la multiplicación: {resultado}")

plt.show()
# Out:
# Resultado de la multiplicación: 972
